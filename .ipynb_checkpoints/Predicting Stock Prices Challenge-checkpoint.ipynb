# %%
import tweepy
import csv
import numpy as np
from textblob import TextBlob
from keras.models import Sequential
from keras.layers import Dense,LSTM
np.random.seed(7)
# Out:
# Using Theano backend.

# %%
#inserting API Keys
consumer_key= 'plPNvWhlzzlOqgrT50P1i9wGj'
consumer_secret= 'NDDtlTwwFYIwbtX5Vru8SBDF0A6fnvmEnOsJzn68P565rvLy4j'
access_token='792294428891152385-pjVppYt7GMvUyFWYugjzfoDZZW74PUH'
access_token_secret='JuJYVEnH6XP6oWcinuyL8WCUtXrWxFQoXKO2zR57VeM75'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
#searcing company on twitter
public_tweets = api.search('Facebook')
print public_tweets[2].text
# Out:
# #サウスト でスタートダッシュキャンペーン実施中！スクラッチ削るだけで虹のコイン最大50,000円分無料プレゼントでガチャし放題【詳細⇒https://t.co/veNdT7hYyH】#サウスト #ワンピース #ルフィ #虹のコイン https://t.co/bF2O0qQ2KQ

# %%
#Defining a threshold for each sentiment
threshold=0
pos_sent_tweet=0
neg_sent_tweet=0
for tweet in public_tweets:
    analysis=TextBlob(tweet.text)
    if analysis.sentiment.polarity>=threshold:
    pos_sent_tweet=pos_sent_tweet+1
    else:
        neg_sent_tweet=neg_sent_tweet+1
if pos_sent_tweet>neg_sent_tweet:
    print "Overall Positive"
else:
    print "Overall Negative"
# Out:
#   File "<ipython-input-6-589e81a9e8fc>", line 8
#     pos_sent_tweet=pos_sent_tweet+1
#                  ^
# IndentationError: expected an indented block

# %%
#data collection
dates = []
prices = []
def get_data(filename):
	with open(filename, 'r') as csvfile:
		csvFileReader = csv.reader(csvfile)
		next(csvFileReader)
		for row in csvFileReader:
			dates.append(int(row[0].split('-')[0]))
			prices.append(float(row[1]))
	return

get_data('fb.csv')
# Out:
# 251

# %%
def predict_prices(dates,prices,x):
    train_size=int(0.80*len(dates))
    TrainX,TrainY=[],[]
    TestX,TestY=[],[]
    cntr=0
    for date in dates:
        if cntr<train_size:
            TrainX.append(date)
        else:
            TestX.append(date)    
    for price in prices:
        if cntr<train_size:
            TrainY.append(price)
        else:
            TestY.append(price)

    TrainX=np.reshape(TrainX,(len(TrainX),1))
    TrainY=np.reshape(TrainY,(len(TrainY),1))
    
    
    for i in range(251):
        print TrainX[i],TrainY[i],'\n'
    
    
    model=Sequential()
    model.add(Dense(32,input_dim=1,init='uniform',activation='relu'))
    model.add(Dense(16,init='uniform',activation='relu'))
    model.add(Dense(1,init='uniform',activation='relu'))
    #model.compile(loss='mean_squared_error',optimizer='adam',metrics=['accuracy'])
    #model.fit(TrainX,TrainY,nb_epoch=150,batch_size=10)

# %%
predict_prices(dates,prices,2)
# Out:
# [28] [ 130.5]
#
# [27] [ 131.74]
#
# [26] [ 131.64]
#
# [25] [ 133.5]
#
# [24] [ 132.72]
#
# [21] [ 129.78]
#
# [20] [ 130.07]
#
# [19] [ 128.74]
#
# [18] [ 128.68]
#
# [17] [ 128.2]
#
# [14] [ 128.49]
#
# [13] [ 128.21]
#
# [12] [ 129.01]
#
# [11] [ 130.23]
#
# [10] [ 129.68]
#
# [7] [ 129.04]
#
# [6] [ 128.43]
#
# [5] [ 128.25]
#
# [4] [ 129.17]
#
# [3] [ 128.38]
#
# [30] [ 128.03]
#
# [29] [ 129.18]
#
# [28] [ 129.21]
#
# [27] [ 127.61]
#
# [26] [ 127.37]
#
# [23] [ 127.56]
#
# [22] [ 130.5]
#
# [21] [ 129.13]
#
# [20] [ 128.65]
#
# [19] [ 129.91]
#
# [16] [ 128.2]
#
# [15] [ 127.98]
#
# [14] [ 126.89]
#
# [13] [ 128.03]
#
# [12] [ 125.96]
#
# [9] [ 129.71]
#
# [8] [ 130.92]
#
# [7] [ 130.04]
#
# [6] [ 126.67]
#
# [2] [ 126.85]
#
# [1] [ 126.38]
#
# [31] [ 125.6]
#
# [30] [ 126.6]
#
# [29] [ 124.35]
#
# [26] [ 124.05]
#
# [25] [ 123.12]
#
# [24] [ 124.47]
#
# [23] [ 124.51]
#
# [22] [ 123.33]
#
# [19] [ 123.6]
#
# [18] [ 124.01]
#
# [17] [ 123.66]
#
# [16] [ 123.5]
#
# [15] [ 124.91]
#
# [12] [ 124.7]
#
# [11] [ 125.2]
#
# [10] [ 125.07]
#
# [9] [ 125.34]
#
# [8] [ 125.25]
#
# [5] [ 124.98]
#
# [4] [ 122.94]
#
# [3] [ 123.09]
#
# [2] [ 124.06]
#
# [1] [ 123.85]
#
# [29] [ 124.65]
#
# [28] [ 127.52]
#
# [27] [ 122.42]
#
# [26] [ 122.]
#
# [25] [ 121.39]
#
# [22] [ 119.9]
#
# [21] [ 121.92]
#
# [20] [ 121.25]
#
# [19] [ 118.99]
#
# [18] [ 117.32]
#
# [15] [ 117.74]
#
# [14] [ 117.5]
#
# [13] [ 118.39]
#
# [12] [ 118.63]
#
# [11] [ 117.71]
#
# [8] [ 116.43]
#
# [7] [ 116.63]
#
# [6] [ 113.36]
#
# [5] [ 113.94]
#
# [1] [ 114.2]
#
# [30] [ 114.67]
#
# [29] [ 113.37]
#
# [28] [ 110.63]
#
# [27] [ 111.57]
#
# [24] [ 111.01]
#
# [23] [ 114.37]
#
# [22] [ 114.65]
#
# [21] [ 114.12]
#
# [20] [ 113.77]
#
# [17] [ 114.42]
#
# [16] [ 113.87]
#
# [15] [ 115.3]
#
# [14] [ 114.07]
#
# [13] [ 115.]
#
# [10] [ 117.54]
#
# [9] [ 118.13]
#
# [8] [ 117.76]
#
# [7] [ 119.24]
#
# [6] [ 118.62]
#
# [3] [ 118.98]
#
# [2] [ 118.69]
#
# [1] [ 118.5]
#
# [31] [ 119.46]
#
# [27] [ 119.56]
#
# [26] [ 118.24]
#
# [25] [ 118.13]
#
# [24] [ 116.24]
#
# [23] [ 117.42]
#
# [20] [ 116.96]
#
# [19] [ 117.05]
#
# [18] [ 116.8]
#
# [17] [ 118.82]
#
# [16] [ 119.38]
#
# [13] [ 120.38]
#
# [12] [ 119.98]
#
# [11] [ 120.41]
#
# [10] [ 119.62]
#
# [9] [ 119.54]
#
# [6] [ 117.16]
#
# [5] [ 118.04]
#
# [4] [ 116.61]
#
# [3] [ 117.52]
#
# [2] [ 117.83]
#
# [29] [ 116.82]
#
# [28] [ 119.58]
#
# [27] [ 107.94]
#
# [26] [ 110.49]
#
# [25] [ 109.87]
#
# [22] [ 111.21]
#
# [21] [ 112.55]
#
# [20] [ 112.43]
#
# [19] [ 111.1]
#
# [18] [ 109.74]
#
# [15] [ 110.79]
#
# [14] [ 110.62]
#
# [13] [ 112.23]
#
# [12] [ 109.34]
#
# [11] [ 110.7]
#
# [8] [ 114.25]
#
# [7] [ 113.79]
#
# [6] [ 112.47]
#
# [5] [ 112.11]
#
# [4] [ 114.07]
#
# [1] [ 113.75]
#
# [31] [ 114.7]
#
# [30] [ 116.73]
#
# [29] [ 113.83]
#
# [28] [ 113.32]
#
# [24] [ 112.13]
#
# [23] [ 112.01]
#
# [22] [ 111.36]
#
# [21] [ 111.66]
#
# [18] [ 111.56]
#
# [17] [ 112.15]
#
# [16] [ 110.49]
#
# [15] [ 109.11]
#
# [14] [ 109.28]
#
# [11] [ 108.48]
#
# [10] [ 107.91]
#
# [9] [ 106.7]
#
# [8] [ 104.78]
#
# [7] [ 108.07]
#
# [4] [ 110.05]
#
# [3] [ 110.25]
#
# [2] [ 109.68]
#
# [1] [ 107.83]
#
# [29] [ 107.6]
#
# [26] [ 108.7]
#
# [25] [ 107.11]
#
# [24] [ 104.21]
#
# [23] [ 106.85]
#
# [22] [ 105.49]
#
# [19] [ 102.55]
#
# [18] [ 105.8]
#
# [17] [ 101.94]
#
# [16] [ 103.8]
#
# [12] [ 103.74]
#
# [11] [ 99.6]
#
# [10] [ 101.55]
#
# [9] [ 97.14]
#
# [8] [ 100.41]
#
# [5] [ 109.51]
#
# [4] [ 111.8]
#
# [3] [ 115.27]
#
# [2] [ 114.8]
#
# [1] [ 112.27]
#
# [29] [ 108.99]
#
# [28] [ 107.2]
#
# [27] [ 97.79]
#
# [26] [ 97.76]
#
# [25] [ 98.72]
#
# [22] [ 96.41]
#
# [21] [ 94.91]
#
# [20] [ 92.83]
#
# [19] [ 96.53]
#
# [15] [ 93.98]
#
# [14] [ 95.85]
#
# [13] [ 100.58]
#
# [12] [ 99.]
#
# [11] [ 97.91]
#
# [8] [ 99.88]
#
# [7] [ 100.5]
#
# [6] [ 101.13]
#
# [5] [ 102.89]
#
# [4] [ 101.95]
#
# [31] [ 106.]
#
# [30] [ 107.]
#
# [29] [ 106.42]
#
# [28] [ 105.02]
#
# [24] [ 104.74]
#
# [23] [ 105.89]
#
# [22] [ 105.22]
#
# [21] [ 104.91]
#
# [18] [ 106.08]
#
# [17] [ 107.49]
#
# [16] [ 105.37]
#
# [15] [ 105.3]
#
# [14] [ 102.28]
#
# [11] [ 104.15]
#
# [10] [ 105.05]
#
# [9] [ 106.18]
#
# [8] [ 104.]
#
# [7] [ 106.48]
#
# [4] [ 104.75]
#
# [3] [ 103.95]
#
# [2] [ 107.]
#
# [1] [ 104.83]
#
# [30] [ 105.84]
#
# [27] [ 105.78]
#
# [25] [ 106.33]
#
# [24] [ 106.]
#
# [23] [ 107.19]
#
# [20] [ 106.84]
#
# [19] [ 107.36]
#
# [18] [ 105.8]
#
# [17] [ 104.62]
#
# [16] [ 103.32]
#
# [13] [ 107.71]
#
# [12] [ 108.48]
#
# [11] [ 108.27]
#
# [10] [ 106.17]
#
# [9] [ 107.]
#
# [6] [ 108.04]
#
# [5] [ 108.8]
#
# [4] [ 103.19]
#
# [3] [ 103.22]
#
# [2] [ 101.72]
